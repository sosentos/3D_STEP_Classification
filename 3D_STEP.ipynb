# %% [markdown]
# <a href="https://colab.research.google.com/github/sosentos/3D_STEP_Classification/blob/main/3D_STEP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#set up environment

! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/

# !conda create --name 3D_STEP_Classification python=3.8
# !conda activate 3D_STEP_Classification

# !git clone https://github.com/sosentos/3D_STEP_Classification

# !conda install pytorch==1.11.0 torchvision==0.12.0 torchaudio==0.11.0 cudatoolkit=11.3 -c pytorch
# !conda install pyg -c pyg
# !conda install -c conda-forge tensorboardx
# !conda install -c anaconda scikit-learn
# !conda install -c conda-forge matplotlib
# !conda install -c anaconda scikit-image
# !conda install -c conda-forge pythonocc-core
# !conda install pandas
# !conda install ipykernel
# !conda install seaborn
# Out:
# --2023-11-28 04:03:27--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104996770 (100M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py37_4.1 100%[===================>] 100.13M   237MB/s    in 0.4s
#
# 2023-11-28 04:03:28 (237 MB/s) - ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’ saved [104996770/104996770]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# \
# Found conflicts! Looking for incompatible packages.
# ...

# %%
# run Graph Classification


# !pwd
# !ls
# %cd 3D_STEP_Classification/Graph_classification/Graph_convertion
# !pwd
# Out:
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion
# 3D_STEP_Classification	Miniconda3-py37_4.12.0-Linux-x86_64.sh	__pycache__
# Graphh			Parser					step_2_graph.py
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion/3D_STEP_Classification/Graph_classification/Graph_convertion
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion/3D_STEP_Classification/Graph_classification/Graph_convertion

# %%
# !pwd
# !ls
# Out:
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion
# Graphh	junk  Miniconda3-py37_4.12.0-Linux-x86_64.sh  Parser  __pycache__  step_2_graph.py
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.5           |   py37h7deecbd_0         115 KB
#     ca-certificates-2023.08.22 |       h06a4308_0         123 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     conda-23.1.0               |   py37h06a4308_0         937 KB
#     numexpr-2.8.4              |   py37he184ba9_0         133 KB
# ...

# %%
# !python step_2_graph.py /content/drive/MyDrive/graph_cad/Step_models /content/drive/MyDrive/graph_cad/Step_graphs/
# Out:
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion
# ['/content/3D_STEP_Classification/Graph_classification/Graph_convertion', '/env/python', '/usr/local/lib/python37.zip', '/usr/local/lib/python3.7', '/usr/local/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/site-packages', '/content/3D_STEP_Classification/Graph_classification/Graph_convertionParser', '/content/3D_STEP_Classification/Graph_classification/Graph_convertionGraphh']
# input file. /content/drive/MyDrive/graph_cad/Step_models
# output file /content/drive/MyDrive/graph_cad/Step_graphs/
# Making 2/2_100.stp graph
# file 2/2_100.stp parsed
#    Number of composed id: 16
#    All nodes obtained
#    All edges obtained
#    Graphh of 2/2_100 model realizing time: 0.0186922550201416 seconds
# Making 2/2_26.stp graph
# file 2/2_26.stp parsed
#    Number of composed id: 16
#    All nodes obtained
#    All edges obtained
#    Graphh of 2/2_26 model realizing time: 0.020887374877929688 seconds
# ...

# %%
# Train the model
# %cd /content/3D_STEP_Classification/Graph_classification/
# Out:
# /content/3D_STEP_Classification/Graph_classification
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     seaborn-0.12.2             |   py37h06a4308_0         488 KB
#     ------------------------------------------------------------
#                                            Total:         488 KB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            pkgs/main/linux-64::seaborn-0.12.2-py37h06a4308_0
#
#
# Proceed ([y]/n)? y
#
#
# ...
#
# ...

# %%
# !python train_GCN.py --run_folder /content/drive/MyDrive/graph_cad/GCN_results/ --dataset /content/drive/MyDrive/graph_cad/Step_graphs/ --datasetname Traceparts_6
# Out:
# The calculations will be performed on the device: cpu
# /content/drive/MyDrive/graph_cad/GCN_results/
# Traceparts_6_11-28
# outdir:/content/drive/MyDrive/graph_cad/GCN_results/results/runs_GCN/Traceparts_6
# Results will be saved in: /content/drive/MyDrive/graph_cad/GCN_results/results/runs_GCN/Traceparts_6
#     The model will be saved as: /content/drive/MyDrive/graph_cad/GCN_results/results/runs_GCN/Traceparts_6/ModelsTraceparts_6_11-28
# Settings: Namespace(batch_size=1, dataset='/content/drive/MyDrive/graph_cad/Step_graphs/', datasetname='Traceparts_6', dropout=0.5, learning_rate=0.0005, num_epochs=50, run_folder='/content/drive/MyDrive/graph_cad/GCN_results/')
# Loading data...
# /content/drive/MyDrive/graph_cad/Step_graphs/
# Loading class: 2
# Loading class: 1
# Loading class: 5
# Loading class: 0
# Loading class: 3
# Loading class: 4
# Loading class: Models
# Loading class: checkpoints
# # classes: 6
# # maximum node tag: 80
# # data: 600
# # training graphs:  486
# ...
