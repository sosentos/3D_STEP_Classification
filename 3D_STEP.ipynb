# %% [markdown]
# <a href="https://colab.research.google.com/github/sosentos/3D_STEP_Classification/blob/main/3D_STEP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#set up environment

! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/

# !conda create --name 3D_STEP_Classification python=3.8
# !conda activate 3D_STEP_Classification

# !git clone https://github.com/divanoLetto/3D_STEP_Classification

# !conda install pytorch==1.11.0 torchvision==0.12.0 torchaudio==0.11.0 cudatoolkit=11.3 -c pytorch
# !conda install pyg -c pyg
# !conda install -c conda-forge tensorboardx
# !conda install -c anaconda scikit-learn
# !conda install -c conda-forge matplotlib
# !conda install -c anaconda scikit-image
# !conda install -c conda-forge pythonocc-core
# Out:
# pytorch-1.11.0       | 1.02 GB   | : 100% 1.0/1 [03:02<00:00, 182.76s/it]
# nettle-3.7.3         | 809 KB    | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# ffmpeg-4.3           | 9.9 MB    | : 100% 1.0/1 [00:02<00:00,  2.37s/it]
# mkl_random-1.2.2     | 287 KB    | : 100% 1.0/1 [00:00<00:00,  6.07it/s]
# libunistring-0.9.10  | 536 KB    | : 100% 1.0/1 [00:00<00:00,  5.93it/s]
# libidn2-2.3.2        | 81 KB     | : 100% 1.0/1 [00:00<00:00,  6.55it/s]
# importlib_metadata-4 | 12 KB     | : 100% 1.0/1 [00:00<00:00,  6.07it/s]
# openh264-2.1.1       | 711 KB    | : 100% 1.0/1 [00:00<00:00,  5.40it/s]
# done
# done
# / By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pyg
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jinja2-3.1.2               |   py37h06a4308_0         209 KB
#     joblib-1.1.1               |   py37h06a4308_0         379 KB
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB
#     libgfortran4-7.5.0         |      ha8ba4b0_17         995 KB
#     markupsafe-2.1.1           |   py37h7f8727e_0          21 KB
#     pyg-2.1.0                  |py37_torch_1.11.0_cu113         829 KB  pyg
#     pyparsing-3.0.9            |   py37h06a4308_0         150 KB
#     pytorch-cluster-1.6.0      |py37_torch_1.11.0_cu113         1.7 MB  pyg
#     pytorch-scatter-2.0.9      |py37_torch_1.11.0_cu113         4.7 MB  pyg
#     pytorch-sparse-0.6.15      |py37_torch_1.11.0_cu113         2.6 MB  pyg
#     scikit-learn-1.0.2         |   py37h51133e4_1         5.5 MB
#     scipy-1.7.3                |   py37hc147768_0        16.4 MB
#     threadpoolctl-2.2.0        |     pyh0d69192_0          16 KB
#     ------------------------------------------------------------
#                                            Total:        33.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   jinja2             pkgs/main/linux-64::jinja2-3.1.2-py37h06a4308_0
#   joblib             pkgs/main/linux-64::joblib-1.1.1-py37h06a4308_0
#   libgfortran-ng     pkgs/main/linux-64::libgfortran-ng-7.5.0-ha8ba4b0_17
#   libgfortran4       pkgs/main/linux-64::libgfortran4-7.5.0-ha8ba4b0_17
#   markupsafe         pkgs/main/linux-64::markupsafe-2.1.1-py37h7f8727e_0
#   pyg                pyg/linux-64::pyg-2.1.0-py37_torch_1.11.0_cu113
#   pyparsing          pkgs/main/linux-64::pyparsing-3.0.9-py37h06a4308_0
#   pytorch-cluster    pyg/linux-64::pytorch-cluster-1.6.0-py37_torch_1.11.0_cu113
#   pytorch-scatter    pyg/linux-64::pytorch-scatter-2.0.9-py37_torch_1.11.0_cu113
#   pytorch-sparse     pyg/linux-64::pytorch-sparse-0.6.15-py37_torch_1.11.0_cu113
#   scikit-learn       pkgs/main/linux-64::scikit-learn-1.0.2-py37h51133e4_1
#   scipy              pkgs/main/linux-64::scipy-1.7.3-py37hc147768_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# pytorch-sparse-0.6.1 | 2.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
# pyg-2.1.0            | 829 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# scikit-learn-1.0.2   | 5.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pytorch-scatter-2.0. | 4.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# pytorch-cluster-1.6. | 1.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pyparsing-3.0.9      | 150 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libgfortran-ng-7.5.0 | 22 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# joblib-1.1.1         | 379 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libgfortran4-7.5.0   | 995 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# markupsafe-2.1.1     | 21 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# threadpoolctl-2.2.0  | 16 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# scipy-1.7.3          | 16.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.2         | 209 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# scikit-learn-1.0.2   | 5.5 MB    | :   0% 0.0028647448420517406/1 [00:00<00:38, 38.75s/it]
#
#
#
#
# pyparsing-3.0.9      | 150 KB    | :  11% 0.10671669011515815/1 [00:00<00:01,  2.00s/it]
#
#
#
#
#
# libgfortran-ng-7.5.0 | 22 KB     | :  73% 0.7294746215494212/1 [00:00<00:00,  2.80it/s]
#
#
#
#
#
#
# joblib-1.1.1         | 379 KB    | :   4% 0.04217321805026088/1 [00:00<00:06,  6.77s/it]
#
#
#
#
#
#
#
# libgfortran4-7.5.0   | 995 KB    | :   2% 0.01607593682266723/1 [00:00<00:46, 47.32s/it]
#
#
#
#
#
#
#
#
# markupsafe-2.1.1     | 21 KB     | :  75% 0.7502175008013188/1 [00:00<00:00,  1.11s/it]
#
#
#
#
#
#
#
#
#
# threadpoolctl-2.2.0  | 16 KB     | :  98% 0.979260056183133/1 [00:00<00:00,  1.13it/s]
#
#
#
#
#
#
#
#
#
#
# scipy-1.7.3          | 16.4 MB   | :   0% 0.0009547060616551086/1 [00:00<15:40, 941.15s/it]
#
# scikit-learn-1.0.2   | 5.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
#
# scikit-learn-1.0.2   | 5.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.11it/s]
#
#
#
#
#
#
#
#
#
#
# scipy-1.7.3          | 16.4 MB   | :  27% 0.27018181544839576/1 [00:00<00:01,  2.70s/it]
#
#
#
#
#
#
#
#
#
#
# scipy-1.7.3          | 16.4 MB   | :  57% 0.5747330491163753/1 [00:01<00:00,  1.24s/it]
#
#
#
#
#
#
#
#
#
#
# scipy-1.7.3          | 16.4 MB   | :  82% 0.817228388776773/1 [00:01<00:00,  1.11it/s]
#
#
#
#
# pyparsing-3.0.9      | 150 KB    | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
#
#
#
#
# pyparsing-3.0.9      | 150 KB    | : 100% 1.0/1 [00:01<00:00,  1.23s/it]
#
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.2         | 209 KB    | :   8% 0.07655001635284774/1 [00:01<00:16, 17.93s/it]
#
#
#
#
#
# libgfortran-ng-7.5.0 | 22 KB     | : 100% 1.0/1 [00:01<00:00,  2.80it/s]
#
#
#
#
#
#
# joblib-1.1.1         | 379 KB    | : 100% 1.0/1 [00:01<00:00,  1.69s/it]
#
#
#
#
#
#
# joblib-1.1.1         | 379 KB    | : 100% 1.0/1 [00:01<00:00,  1.69s/it]
#
#
#
#
#
#
#
# libgfortran4-7.5.0   | 995 KB    | : 100% 1.0/1 [00:01<00:00,  1.76s/it]
#
#
#
#
#
#
#
# libgfortran4-7.5.0   | 995 KB    | : 100% 1.0/1 [00:01<00:00,  1.76s/it]
#
#
#
#
#
#
#
#
# markupsafe-2.1.1     | 21 KB     | : 100% 1.0/1 [00:02<00:00,  2.46s/it]
#
#
#
#
#
#
#
#
# markupsafe-2.1.1     | 21 KB     | : 100% 1.0/1 [00:02<00:00,  2.46s/it]
#
#
#
#
#
#
#
#
#
# threadpoolctl-2.2.0  | 16 KB     | : 100% 1.0/1 [00:02<00:00,  1.13it/s]
#
#
#
# pytorch-cluster-1.6. | 1.7 MB    | : 100% 1.0/1 [00:02<00:00,  2.75s/it]
#
#
#
# pytorch-cluster-1.6. | 1.7 MB    | : 100% 1.0/1 [00:02<00:00,  2.75s/it]
# pyg-2.1.0            | 829 KB    | : 100% 1.0/1 [00:03<00:00,  3.15s/it]
# pyg-2.1.0            | 829 KB    | : 100% 1.0/1 [00:03<00:00,  3.15s/it]
#
#
#
#
#
#
#
#
#
#
# scipy-1.7.3          | 16.4 MB   | : 100% 1.0/1 [00:04<00:00,  1.11it/s]
#
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.2         | 209 KB    | : 100% 1.0/1 [00:04<00:00,  4.43s/it]
#
#
#
#
#
#
#
#
#
#
#
# jinja2-3.1.2         | 209 KB    | : 100% 1.0/1 [00:04<00:00,  4.43s/it]
#
#
# pytorch-scatter-2.0. | 4.7 MB    | : 100% 1.0/1 [00:06<00:00,  6.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# |
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# | WARNING conda.models.version:get_matcher(549): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tensorboardx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.11.17 |       hbcca054_0         151 KB  conda-forge
#     certifi-2023.11.17         |     pyhd8ed1ab_0         155 KB  conda-forge
#     libprotobuf-3.15.8         |       h780b84a_0         2.5 MB  conda-forge
#     protobuf-3.15.8            |   py37hcd2ae1e_0         334 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     tensorboardx-2.2           |     pyhd3eb1b0_0          86 KB
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.15.8-h780b84a_0
#   protobuf           conda-forge/linux-64::protobuf-3.15.8-py37hcd2ae1e_0
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m
#   tensorboardx       pkgs/main/noarch::tensorboardx-2.2-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.08.22~ --> conda-forge::ca-certificates-2023.11.17-hbcca054_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7~ --> conda-forge/noarch::certifi-2023.11.17-pyhd8ed1ab_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# libprotobuf-3.15.8   | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
# ca-certificates-2023 | 151 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# python_abi-3.7       | 4 KB      | :   0% 0/1 [00:00<?, ?it/s]
#
#
# tensorboardx-2.2     | 86 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# certifi-2023.11.17   | 155 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# protobuf-3.15.8      | 334 KB    | :   0% 0/1 [00:00<?, ?it/s]
# ca-certificates-2023 | 151 KB    | :  21% 0.2126176865628062/1 [00:00<00:00,  2.08it/s]
#
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  9.85it/s]
#
#
# tensorboardx-2.2     | 86 KB     | :  74% 0.7409216298105187/1 [00:00<00:00,  7.36it/s]
#
#
#
# certifi-2023.11.17   | 155 KB    | :  10% 0.1030835729430788/1 [00:00<00:00,  1.01it/s]
#
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  9.85it/s]
#
#
#
#
# libprotobuf-3.15.8   | 2.5 MB    | :   1% 0.0063021468611008215/1 [00:00<00:38, 38.47s/it]
# ca-certificates-2023 | 151 KB    | : 100% 1.0/1 [00:00<00:00,  3.96it/s]
# libprotobuf-3.15.8   | 2.5 MB    | :  25% 0.25208587444403285/1 [00:00<00:00,  1.08s/it]
#
#
# libprotobuf-3.15.8   | 2.5 MB    | :  71% 0.7121425953043928/1 [00:00<00:00,  2.18it/s]
#
#
#
# certifi-2023.11.17   | 155 KB    | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
#
#
#
# certifi-2023.11.17   | 155 KB    | : 100% 1.0/1 [00:00<00:00,  1.74it/s]
#
#
#
#
# protobuf-3.15.8      | 334 KB    | : 100% 1.0/1 [00:00<00:00,  1.62it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       h06a4308_0         130 KB  anaconda
#     certifi-2020.6.20          |     pyhd3eb1b0_3         159 KB  anaconda
#     openssl-1.1.1w             |       h7f8727e_0         3.8 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2023.11.~ --> anaconda::ca-certificates-2023.08.22-h06a4308_0
#   certifi            conda-forge::certifi-2023.11.17-pyhd8~ --> anaconda::certifi-2020.6.20-pyhd3eb1b0_3
#   openssl                                         pkgs/main --> anaconda
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# openssl-1.1.1w       | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
# ca-certificates-2023 | 130 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# certifi-2020.6.20    | 159 KB    | :   0% 0/1 [00:00<?, ?it/s]
# openssl-1.1.1w       | 3.8 MB    | :   0% 0.004097420780655692/1 [00:00<00:30, 30.25s/it]
#
# openssl-1.1.1w       | 3.8 MB    | :  68% 0.6842692703695006/1 [00:00<00:00,  3.66it/s]
# ca-certificates-2023 | 130 KB    | : 100% 1.0/1 [00:00<00:00,  4.72it/s]
# ca-certificates-2023 | 130 KB    | : 100% 1.0/1 [00:00<00:00,  4.72it/s]
#
# certifi-2020.6.20    | 159 KB    | : 100% 1.0/1 [00:00<00:00,  4.17it/s]
#
#
#
#
#
# done
# done
# done
# - WARNING conda.models.version:get_matcher(549): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# /
# Warning: 2 possible package resolutions (only showing differing packages):
#   - anaconda/linux-64::openssl-1.1.1w-h7f8727e_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     icu-67.1                   |       he1b5a44_0        12.9 MB  conda-forge
#     kiwisolver-1.4.4           |   py37h6a678d5_0          74 KB
#     libstdcxx-ng-13.2.0        |       h7e041cc_3         3.7 MB  conda-forge
#     matplotlib-3.2.2           |                1           6 KB  conda-forge
#     matplotlib-base-3.2.2      |   py37h1d35a4c_1         7.0 MB  conda-forge
#     python-dateutil-2.8.2      |     pyhd8ed1ab_0         240 KB  conda-forge
#     tornado-6.1                |   py37h540881e_3         646 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        24.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   icu                conda-forge/linux-64::icu-67.1-he1b5a44_0
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.4.4-py37h6a678d5_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.2.2-1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.2.2-py37h1d35a4c_1
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.2-pyhd8ed1ab_0
#   tornado            conda-forge/linux-64::tornado-6.1-py37h540881e_3
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2023.08.22-~ --> conda-forge::ca-certificates-2023.11.17-hbcca054_0
#   certifi            anaconda::certifi-2020.6.20-pyhd3eb1b~ --> conda-forge::certifi-2023.11.17-pyhd8ed1ab_0
#   libgcc-ng                               9.3.0-h5101ec6_17 --> 11.2.0-h1234567_1
#   libgomp                                 9.3.0-h5101ec6_17 --> 11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-9.3.0-hd4cf53~ --> conda-forge::libstdcxx-ng-13.2.0-h7e041cc_3
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# tornado-6.1          | 646 KB    | :   0% 0/1 [00:00<?, ?it/s]
# icu-67.1             | 12.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# python-dateutil-2.8. | 240 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# kiwisolver-1.4.4     | 74 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# matplotlib-base-3.2. | 7.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# cycler-0.11.0        | 12 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libstdcxx-ng-13.2.0  | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# tornado-6.1          | 646 KB    | :   2% 0.02478691183278517/1 [00:00<00:04,  4.35s/it]
# icu-67.1             | 12.9 MB   | :   0% 0.001215743402158182/1 [00:00<01:45, 105.45s/it]
#
#
# kiwisolver-1.4.4     | 74 KB     | :  22% 0.21709863783325384/1 [00:00<00:00,  1.73it/s]
#
# python-dateutil-2.8. | 240 KB    | :   7% 0.06660514580038783/1 [00:00<00:01,  2.07s/it]
#
# python-dateutil-2.8. | 240 KB    | :  13% 0.13321029160077566/1 [00:00<00:02,  2.86s/it]
#
#
#
# matplotlib-base-3.2. | 7.0 MB    | :   0% 0.002217984682584786/1 [00:00<02:39, 159.48s/it]
# icu-67.1             | 12.9 MB   | :   3% 0.03282507185827092/1 [00:00<00:09, 10.11s/it]
#
#
# tornado-6.1          | 646 KB    | : 100% 1.0/1 [00:00<00:00,  2.52it/s]
# icu-67.1             | 12.9 MB   | :   9% 0.08874926835754729/1 [00:00<00:03,  4.24s/it]
#
#
#
# matplotlib-base-3.2. | 7.0 MB    | :  12% 0.12420714222474802/1 [00:00<00:02,  2.83s/it]
#
#
#
#
#
# libstdcxx-ng-13.2.0  | 3.7 MB    | :   0% 0.004263402499128271/1 [00:00<01:47, 108.20s/it]
#
#
#
#
# cycler-0.11.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00,  2.10it/s]
#
# python-dateutil-2.8. | 240 KB    | : 100% 1.0/1 [00:00<00:00,  2.52it/s]
#
# python-dateutil-2.8. | 240 KB    | : 100% 1.0/1 [00:00<00:00,  2.52it/s]
# icu-67.1             | 12.9 MB   | :  19% 0.19208745754099277/1 [00:00<00:01,  2.11s/it]
#
#
#
# matplotlib-base-3.2. | 7.0 MB    | :  31% 0.3082998708792853/1 [00:00<00:00,  1.28s/it]
#
#
#
#
#
# libstdcxx-ng-13.2.0  | 3.7 MB    | :  38% 0.37944282242241617/1 [00:00<00:00,  1.12s/it]
#
#
#
#
#
#
# matplotlib-3.2.2     | 6 KB      | : 100% 1.0/1 [00:00<00:00,  1.58it/s]
# icu-67.1             | 12.9 MB   | :  32% 0.31852477136544366/1 [00:00<00:00,  1.44s/it]
#
#
#
# matplotlib-base-3.2. | 7.0 MB    | :  56% 0.5567141553287813/1 [00:00<00:00,  1.25it/s]
#
#
#
#
#
# libstdcxx-ng-13.2.0  | 3.7 MB    | :  80% 0.7972562673369867/1 [00:00<00:00,  1.68it/s]
#
#
#
# matplotlib-base-3.2. | 7.0 MB    | :  96% 0.9603873675592124/1 [00:00<00:00,  2.03it/s]
# icu-67.1             | 12.9 MB   | :  54% 0.5446530441668656/1 [00:00<00:00,  1.14it/s]
# icu-67.1             | 12.9 MB   | :  95% 0.9507113404876983/1 [00:00<00:00,  1.99it/s]
#
#
# kiwisolver-1.4.4     | 74 KB     | : 100% 1.0/1 [00:00<00:00,  1.10it/s]
#
#
# kiwisolver-1.4.4     | 74 KB     | : 100% 1.0/1 [00:00<00:00,  1.10it/s]
#
#
#
#
# cycler-0.11.0        | 12 KB     | : 100% 1.0/1 [00:01<00:00,  2.10it/s]
#
#
#
#
#
#
# matplotlib-3.2.2     | 6 KB      | : 100% 1.0/1 [00:01<00:00,  1.58it/s]
#
#
#
#
#
# libstdcxx-ng-13.2.0  | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.68it/s]
#
#
#
# matplotlib-base-3.2. | 7.0 MB    | : 100% 1.0/1 [00:02<00:00,  2.03it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.10.0
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-image
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py37h06a4308_0         152 KB  anaconda
#     cloudpickle-2.0.0          |     pyhd3eb1b0_0          31 KB  anaconda
#     conda-23.1.0               |   py37h06a4308_0         955 KB  anaconda
#     cytoolz-0.12.0             |   py37h5eee18b_0         387 KB  anaconda
#     dask-core-2021.10.0        |     pyhd3eb1b0_0         772 KB  anaconda
#     fsspec-2022.11.0           |   py37h06a4308_0         198 KB  anaconda
#     imageio-2.9.0              |     pyhd3eb1b0_0         3.1 MB  anaconda
#     locket-1.0.0               |   py37h06a4308_0          11 KB  anaconda
#     networkx-2.6.3             |     pyhd3eb1b0_0         1.5 MB  anaconda
#     packaging-22.0             |   py37h06a4308_0          63 KB  anaconda
#     partd-1.2.0                |     pyhd3eb1b0_1          18 KB  anaconda
#     pywavelets-1.3.0           |   py37h7f8727e_0         4.4 MB  anaconda
#     pyyaml-6.0                 |   py37h5eee18b_1         180 KB  anaconda
#     scikit-image-0.19.2        |   py37h51133e4_0        11.6 MB  anaconda
#     tifffile-2020.10.1         |   py37hdd07704_2         260 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        23.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cloudpickle        anaconda/noarch::cloudpickle-2.0.0-pyhd3eb1b0_0
#   cytoolz            anaconda/linux-64::cytoolz-0.12.0-py37h5eee18b_0
#   dask-core          anaconda/noarch::dask-core-2021.10.0-pyhd3eb1b0_0
#   fsspec             anaconda/linux-64::fsspec-2022.11.0-py37h06a4308_0
#   imageio            anaconda/noarch::imageio-2.9.0-pyhd3eb1b0_0
#   locket             anaconda/linux-64::locket-1.0.0-py37h06a4308_0
#   networkx           anaconda/noarch::networkx-2.6.3-pyhd3eb1b0_0
#   packaging          anaconda/linux-64::packaging-22.0-py37h06a4308_0
#   partd              anaconda/noarch::partd-1.2.0-pyhd3eb1b0_1
#   pywavelets         anaconda/linux-64::pywavelets-1.3.0-py37h7f8727e_0
#   pyyaml             anaconda/linux-64::pyyaml-6.0-py37h5eee18b_1
#   scikit-image       anaconda/linux-64::scikit-image-0.19.2-py37h51133e4_0
#   tifffile           anaconda/linux-64::tifffile-2020.10.1-py37hdd07704_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2023.11.~ --> anaconda::ca-certificates-2023.08.22-h06a4308_0
#   certifi            conda-forge/noarch::certifi-2023.11.1~ --> anaconda/linux-64::certifi-2022.12.7-py37h06a4308_0
#   conda                                           pkgs/main --> anaconda
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# cytoolz-0.12.0       | 387 KB    | :   0% 0/1 [00:00<?, ?it/s]
# dask-core-2021.10.0  | 772 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# cloudpickle-2.0.0    | 31 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pyyaml-6.0           | 180 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# partd-1.2.0          | 18 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pywavelets-1.3.0     | 4.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# fsspec-2022.11.0     | 198 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# networkx-2.6.3       | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# imageio-2.9.0        | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# locket-1.0.0         | 11 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# scikit-image-0.19.2  | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# tifffile-2020.10.1   | 260 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.1.0         | 955 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# partd-1.2.0          | 18 KB     | :  87% 0.8737201365187713/1 [00:00<00:00,  8.43it/s]
#
#
#
# partd-1.2.0          | 18 KB     | : 100% 1.0/1 [00:00<00:00,  8.43it/s]
# dask-core-2021.10.0  | 772 KB    | :   2% 0.02071888878772244/1 [00:00<00:06,  6.34s/it]
#
# cloudpickle-2.0.0    | 31 KB     | :  51% 0.5143305603515932/1 [00:00<00:00,  3.45it/s]
#
# cytoolz-0.12.0       | 387 KB    | :   4% 0.041349825479709966/1 [00:00<00:08,  9.32s/it]
#
#
#
#
#
# fsspec-2022.11.0     | 198 KB    | :   8% 0.08092102988605664/1 [00:00<00:04,  4.54s/it]
#
#
# pyyaml-6.0           | 180 KB    | :   9% 0.08912145953796528/1 [00:00<00:03,  4.19s/it]
# dask-core-2021.10.0  | 772 KB    | : 100% 1.0/1 [00:00<00:00,  2.70it/s]
# dask-core-2021.10.0  | 772 KB    | : 100% 1.0/1 [00:00<00:00,  2.70it/s]
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     | :  26% 0.2556365168276357/1 [00:00<00:01,  1.76s/it]
#
#
#
#
#
#
#
#
# imageio-2.9.0        | 3.1 MB    | :   1% 0.0050086407000357975/1 [00:00<01:29, 90.26s/it]
#
#
#
#
#
#
# networkx-2.6.3       | 1.5 MB    | :   1% 0.010546623297454816/1 [00:00<00:42, 42.99s/it]
#
#
#
#
# pywavelets-1.3.0     | 4.4 MB    | :   0% 0.003589148521393047/1 [00:00<02:06, 126.54s/it]
#
#
#
#
#
# fsspec-2022.11.0     | 198 KB    | : 100% 1.0/1 [00:00<00:00,  2.69it/s]
#
#
#
#
#
# fsspec-2022.11.0     | 198 KB    | : 100% 1.0/1 [00:00<00:00,  2.69it/s]
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | :  11% 0.10551601996457897/1 [00:00<00:04,  4.88s/it]
#
#
# pyyaml-6.0           | 180 KB    | : 100% 1.0/1 [00:00<00:00,  2.28it/s]
#
#
# pyyaml-6.0           | 180 KB    | : 100% 1.0/1 [00:00<00:00,  2.28it/s]
#
#
#
#
# pywavelets-1.3.0     | 4.4 MB    | :  17% 0.1686899805054732/1 [00:00<00:02,  2.88s/it]
#
#
#
#
#
#
# networkx-2.6.3       | 1.5 MB    | :  49% 0.4851446716829215/1 [00:00<00:00,  1.00it/s]
#
#
#
#
#
#
#
#
# cytoolz-0.12.0       | 387 KB    | : 100% 1.0/1 [00:00<00:00,  1.83it/s]
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     | : 100% 1.0/1 [00:00<00:00,  1.75it/s]
#
#
#
#
#
#
#
# packaging-22.0       | 63 KB     | : 100% 1.0/1 [00:00<00:00,  1.75it/s]
#
#
#
#
# pywavelets-1.3.0     | 4.4 MB    | :  83% 0.8326824569631869/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
#
#
# imageio-2.9.0        | 3.1 MB    | :  30% 0.3005184420021479/1 [00:00<00:01,  1.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# tifffile-2020.10.1   | 260 KB    | :   6% 0.06148972981899111/1 [00:00<00:11, 12.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.1.0         | 955 KB    | :   2% 0.01675540020085209/1 [00:00<00:46, 47.62s/it]
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | : 100% 1.0/1 [00:00<00:00,  1.49it/s]
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 152 KB    | : 100% 1.0/1 [00:00<00:00,  1.49it/s]
#
#
#
#
#
#
#
#
#
# locket-1.0.0         | 11 KB     | : 100% 1.0/1 [00:01<00:00,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
# scikit-image-0.19.2  | 11.6 MB   | :   0% 0.0013470174875492963/1 [00:01<14:45, 887.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.1.0         | 955 KB    | :  27% 0.2680864032136334/1 [00:01<00:02,  3.63s/it]
#
#
#
#
#
#
#
#
# imageio-2.9.0        | 3.1 MB    | :  79% 0.7863565899056203/1 [00:01<00:00,  1.18s/it]
#
#
#
#
#
#
# networkx-2.6.3       | 1.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
# networkx-2.6.3       | 1.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
#
#
#
#
#
# scikit-image-0.19.2  | 11.6 MB   | :   6% 0.05926876945216904/1 [00:02<00:26, 28.51s/it]
#
#
#
#
# pywavelets-1.3.0     | 4.4 MB    | : 100% 1.0/1 [00:02<00:00,  1.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# tifffile-2020.10.1   | 260 KB    | : 100% 1.0/1 [00:02<00:00,  1.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# tifffile-2020.10.1   | 260 KB    | : 100% 1.0/1 [00:02<00:00,  1.95s/it]
#
#
#
#
#
#
#
#
#
#
#
# scikit-image-0.19.2  | 11.6 MB   | :  20% 0.20474665810749304/1 [00:02<00:05,  6.86s/it]
#
#
#
#
#
#
#
#
#
# locket-1.0.0         | 11 KB     | : 100% 1.0/1 [00:02<00:00,  1.19s/it]
#
#
#
#
#
#
#
#
#
#
#
# scikit-image-0.19.2  | 11.6 MB   | :  61% 0.6061578693971834/1 [00:02<00:00,  1.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# scikit-image-0.19.2  | 11.6 MB   | :  94% 0.9402182063094089/1 [00:02<00:00,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.1.0         | 955 KB    | : 100% 1.0/1 [00:02<00:00,  2.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-23.1.0         | 955 KB    | : 100% 1.0/1 [00:02<00:00,  2.43s/it]
#
#
#
#
#
#
#
#
# imageio-2.9.0        | 3.1 MB    | : 100% 1.0/1 [00:03<00:00,  3.81s/it]
#
#
#
#
#
#
#
#
# imageio-2.9.0        | 3.1 MB    | : 100% 1.0/1 [00:03<00:00,  3.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# / WARNING conda.models.version:get_matcher(549): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# \ WARNING conda.models.version:get_matcher(549): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(549): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.6.0.*, but conda is ignoring the .* and treating it as 1.6.0
# | WARNING conda.models.version:get_matcher(549): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# /
# Warning: 2 possible package resolutions (only showing differing packages):
#   - anaconda/linux-64::conda-23.1.0-py37h06a4308_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pythonocc-core
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     expat-2.4.8                |       h27087fc_0         187 KB  conda-forge
#     fontconfig-2.14.0          |       h8e229c2_0         305 KB  conda-forge
#     libuuid-2.32.1             |    h7f98852_1000          28 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     occt-7.4.0                 |       h9121d39_3        28.1 MB  conda-forge
#     openssl-1.1.1o             |       h166bdaf_0         2.1 MB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pythonocc-core-7.4.1       |   py37h2700f40_0        53.7 MB  conda-forge
#     tbb-2020.2                 |       h4bd325d_4         1.5 MB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.7.2          |       h7f98852_0         941 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxt-1.2.1           |       h7f98852_2         375 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        87.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   expat              conda-forge/linux-64::expat-2.4.8-h27087fc_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.0-h8e229c2_0
#   libuuid            conda-forge/linux-64::libuuid-2.32.1-h7f98852_1000
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   occt               conda-forge/linux-64::occt-7.4.0-h9121d39_3
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pythonocc-core     conda-forge/linux-64::pythonocc-core-7.4.1-py37h2700f40_0
#   tbb                conda-forge/linux-64::tbb-2020.2-h4bd325d_4
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.7.2-h7f98852_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxt         conda-forge/linux-64::xorg-libxt-1.2.1-h7f98852_2
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2023.08.22-~ --> conda-forge::ca-certificates-2023.11.17-hbcca054_0
#   certifi            anaconda/linux-64::certifi-2022.12.7-~ --> conda-forge/noarch::certifi-2023.11.17-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   openssl               anaconda::openssl-1.1.1w-h7f8727e_0 --> conda-forge::openssl-1.1.1o-h166bdaf_0
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# pthread-stubs-0.4    | 5 KB      | :   0% 0/1 [00:00<?, ?it/s]
# pythonocc-core-7.4.1 | 53.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# xorg-libxau-1.0.9    | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# xorg-xproto-7.0.31   | 73 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# xorg-libsm-1.2.3     | 26 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libxcb-1.13          | 391 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# xorg-libx11-1.7.2    | 941 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libuuid-2.32.1       | 28 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# expat-2.4.8          | 187 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# fontconfig-2.14.0    | 305 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# xorg-kbproto-1.0.7   | 27 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1o       | 2.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.3  | 19 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.0.10   | 58 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2020.2           | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.2.1     | 375 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# xorg-libxau-1.0.9    | 13 KB     | : 100% 1.0/1 [00:00<00:00,  7.34it/s]
#
#
# pthread-stubs-0.4    | 5 KB      | : 100% 1.0/1 [00:00<00:00,  6.54it/s]
#
#
#
# xorg-libsm-1.2.3     | 26 KB     | :  62% 0.6215006448676125/1 [00:00<00:00,  4.47it/s]
#
# pthread-stubs-0.4    | 5 KB      | : 100% 1.0/1 [00:00<00:00,  6.54it/s]
#
#
#
#
#
#
# libuuid-2.32.1       | 28 KB     | :  58% 0.579267430349314/1 [00:00<00:00,  3.34it/s]
#
#
#
# xorg-libsm-1.2.3     | 26 KB     | : 100% 1.0/1 [00:00<00:00,  4.47it/s]
#
#
#
#
# libxcb-1.13          | 391 KB    | :   4% 0.040970754823141074/1 [00:00<00:04,  5.12s/it]
#
#
#
#
#
#
#
#
# fontconfig-2.14.0    | 305 KB    | :   5% 0.052505752430762526/1 [00:00<00:03,  4.03s/it]
#
#
#
#
#
# xorg-libx11-1.7.2    | 941 KB    | :   2% 0.01700569416737074/1 [00:00<00:12, 12.68s/it]
#
#
#
#
#
#
#
# expat-2.4.8          | 187 KB    | :   9% 0.08540405856933607/1 [00:00<00:02,  2.55s/it]
#
#
# xorg-xproto-7.0.31   | 73 KB     | : 100% 1.0/1 [00:00<00:00,  4.44it/s]
#
#
# xorg-xproto-7.0.31   | 73 KB     | : 100% 1.0/1 [00:00<00:00,  4.44it/s]
#
#
#
#
#
#
#
#
#
# xorg-kbproto-1.0.7   | 27 KB     | :  60% 0.5993123125320068/1 [00:00<00:00,  2.27it/s]
#
#
#
#
#
#
# libuuid-2.32.1       | 28 KB     | : 100% 1.0/1 [00:00<00:00,  3.61it/s]
#
#
#
#
#
#
# libuuid-2.32.1       | 28 KB     | : 100% 1.0/1 [00:00<00:00,  3.61it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1o       | 2.1 MB    | :   1% 0.007361676506798228/1 [00:00<00:47, 48.18s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.3  | 19 KB     | :  86% 0.8566349471923037/1 [00:00<00:00,  2.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.0.10   | 58 KB     | :  28% 0.2758481353649297/1 [00:00<00:00,  1.31s/it]
#
#
#
#
#
#
#
# expat-2.4.8          | 187 KB    | : 100% 1.0/1 [00:00<00:00,  3.11it/s]
#
#
#
#
#
#
#
# expat-2.4.8          | 187 KB    | : 100% 1.0/1 [00:00<00:00,  3.11it/s]
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1o       | 2.1 MB    | :  24% 0.23557364821754329/1 [00:00<00:01,  1.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.2.1     | 375 KB    | :   4% 0.04268467426362163/1 [00:00<00:10, 11.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :   0% 0.0005564030121018334/1 [00:00<14:36, 876.82s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :   0% 0.0002909340413959507/1 [00:00<30:06, 1807.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2020.2           | 1.5 MB    | :   1% 0.01070822377730241/1 [00:00<00:47, 48.36s/it]
#
#
#
#
#
#
#
#
# fontconfig-2.14.0    | 305 KB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
#
#
#
#
#
#
#
#
# fontconfig-2.14.0    | 305 KB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2020.2           | 1.5 MB    | :  50% 0.5032865175332132/1 [00:00<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :   3% 0.032827777714008174/1 [00:00<00:16, 16.85s/it]
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1o       | 2.1 MB    | :  64% 0.6404658560914458/1 [00:00<00:00,  1.19it/s]
# pythonocc-core-7.4.1 | 53.7 MB   | :   0% 0.0034912084967514082/1 [00:00<02:43, 164.44s/it]
#
#
#
#
# libxcb-1.13          | 391 KB    | : 100% 1.0/1 [00:00<00:00,  1.43it/s]
#
#
#
#
# libxcb-1.13          | 391 KB    | : 100% 1.0/1 [00:00<00:00,  1.43it/s]
#
#
#
#
#
#
#
#
#
# xorg-kbproto-1.0.7   | 27 KB     | : 100% 1.0/1 [00:00<00:00,  1.15it/s]
#
#
#
#
#
#
#
#
#
# xorg-kbproto-1.0.7   | 27 KB     | : 100% 1.0/1 [00:00<00:00,  1.15it/s]
# pythonocc-core-7.4.1 | 53.7 MB   | :   5% 0.045385710457768305/1 [00:01<00:15, 16.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  11% 0.11183700543246852/1 [00:01<00:06,  6.93s/it]
#
#
#
#
#
# xorg-libx11-1.7.2    | 941 KB    | : 100% 1.0/1 [00:01<00:00,  1.01s/it]
#
#
#
#
#
# xorg-libx11-1.7.2    | 941 KB    | : 100% 1.0/1 [00:01<00:00,  1.01s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxdmcp-1.1.3  | 19 KB     | : 100% 1.0/1 [00:01<00:00,  2.39it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  19% 0.19251544218723438/1 [00:01<00:03,  3.91s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :   9% 0.0866983443359933/1 [00:01<00:07,  8.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.0.10   | 58 KB     | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libice-1.0.10   | 58 KB     | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  11% 0.106190925109522/1 [00:01<00:07,  8.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  23% 0.23424566809487188/1 [00:01<00:02,  3.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.2.1     | 375 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-libxt-1.2.1     | 375 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  27% 0.2709682668935929/1 [00:01<00:03,  5.27s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  12% 0.12364696759327903/1 [00:01<00:09, 11.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2020.2           | 1.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tbb-2020.2           | 1.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  30% 0.29878841749868457/1 [00:02<00:05,  7.83s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  14% 0.13702993349749276/1 [00:02<00:14, 16.56s/it]
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1o       | 2.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.31s/it]
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1o       | 2.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  44% 0.44178399160885573/1 [00:02<00:01,  3.44s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  21% 0.2141274544674197/1 [00:02<00:05,  6.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  55% 0.5525081910171206/1 [00:02<00:01,  2.42s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  31% 0.306935413672728/1 [00:02<00:02,  3.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  68% 0.681593689824746/1 [00:02<00:00,  1.76s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  37% 0.37355930915240065/1 [00:02<00:01,  2.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  83% 0.8262584729712227/1 [00:02<00:00,  1.34s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  44% 0.442510676963241/1 [00:02<00:01,  2.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | :  96% 0.9609080018998664/1 [00:02<00:00,  1.14s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  51% 0.5108801766912894/1 [00:02<00:01,  2.15s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  57% 0.5716853913430431/1 [00:08<00:13, 31.35s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  69% 0.6909683483153829/1 [00:08<00:05, 17.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# occt-7.4.0           | 28.1 MB   | : 100% 1.0/1 [00:08<00:00,  1.14s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  82% 0.8233433371505404/1 [00:09<00:01, 10.58s/it]
# pythonocc-core-7.4.1 | 53.7 MB   | :  93% 0.9254611856805192/1 [00:09<00:00,  7.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# run Graph Classification


# !pwd
# !ls
# %cd 3D_STEP_Classification/Graph_classification/Graph_convertion
# !pwd
# Out:
# /content
# 3D_STEP_Classification	drive  Miniconda3-py37_4.12.0-Linux-x86_64.sh  sample_data
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion

# %%
# !pwd
# !ls
# !python --version
# Out:
# /content/3D_STEP_Classification/Graph_classification/Graph_convertion
# Graphh	Parser	__pycache__  step_2_graph.py
# Python 3.7.13

# %%
# !python -m Parser step_2_graph.py drive/MyDrive/graph_cad/Step_models drive/MyDrive/graph_cad/Step_graphs/
# Out:
# /usr/local/bin/python: No module named Parser.__main__; 'Parser' is a package and cannot be directly executed
